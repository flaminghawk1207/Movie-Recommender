# %%
#all the libraries
import re
import string
import nltk
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, SpatialDropout1D
from tensorflow.keras.callbacks import Callback, EarlyStopping

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/movies.csv', header=None, engine='python')

# %%
df.dropna(axis=1,inplace=True)

# %%
df
# Out:
#            0                                                  1         2
# 0         id                                               text     genre
# 1          0  eady dead, maybe even wishing he was. INT. 2ND...  thriller
# 2          2  t, summa cum laude and all. And I'm about to l...    comedy
# 3          3   up Come, I have a surprise.... She takes him ...     drama
# 4          4  ded by the two detectives. INT. JEFF'S APARTME...  thriller
# ...      ...                                                ...       ...
# 22575  28161  n in the world to decide what I'm going to do ...     drama
# 22576  28162  shards. BOJO LAZ! Laz pushes Deke back through...     drama
# 22577  28163  OTTIE You've got a thing about Ernie's, haven'...  thriller
# 22578  28165  ....with marked skill and dexterity . LANA wry...    action
# 22579  28166  rd walks off down the hallway, leaving his pos...    comedy
#
# [22580 rows x 3 columns]

# %%
df.columns=df.iloc[0]

# %%
df=df.tail(-1)

# %%
df
# Out:
# 0         id                                               text     genre
# 1          0  eady dead, maybe even wishing he was. INT. 2ND...  thriller
# 2          2  t, summa cum laude and all. And I'm about to l...    comedy
# 3          3   up Come, I have a surprise.... She takes him ...     drama
# 4          4  ded by the two detectives. INT. JEFF'S APARTME...  thriller
# 5          5  nd dismounts, just as the other children reach...     drama
# ...      ...                                                ...       ...
# 22575  28161  n in the world to decide what I'm going to do ...     drama
# 22576  28162  shards. BOJO LAZ! Laz pushes Deke back through...     drama
# 22577  28163  OTTIE You've got a thing about Ernie's, haven'...  thriller
# 22578  28165  ....with marked skill and dexterity . LANA wry...    action
# 22579  28166  rd walks off down the hallway, leaving his pos...    comedy
#
# [22579 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
train_df,test_df=tts(df,test_size=0.3)

# %%
train_df
# Out:
# 0         id                                               text     genre
# 20162  25185  you around, just to make me laugh. 467A SHOT O...  thriller
# 2713    3406  right hand shakes off of the wheel a bit. He g...  thriller
# 20678  25827  sn't even have to be gold JOE How can you be s...    comedy
# 18711  23404  here. I used to have lunch with him. John Birc...     drama
# 7785    9797  leet Officers, jumping off the dish and flying...  thriller
# ...      ...                                                ...       ...
# 7972   10033  n emptiness began to grow There's something ou...     other
# 6519    8199  ther...? shrugs Probably stumbling home, propo...     other
# 16345  20439  ppears behind it. ANGLE BEHIND THE STATUE Dani...    action
# 10398  13058  if we don't move. This guy is everything they ...  thriller
# 17649  22068  couch preparing his morning joint. WAYNE She's...    action
#
# [15805 rows x 3 columns]

# %%
test_df
# Out:
# 0         id                                               text     genre
# 8390   10571   in a pantsuit, heels, and pink angora sweater...     drama
# 14689  18380  FILM EDITORS CONRAD BUFF MARK GOLDBLATT, A.C.E...  thriller
# 5399    6785  e house was a collection of 36 artifacts, all ...    comedy
# 2598    3263  could they have evolved so quickly...? David d...  thriller
# 13049  16361  ard on Korda's hair. Pushes the gun tighter ag...     drama
# ...      ...                                                ...       ...
# 20211  25247  s surprised to see her. She immediately crosse...    action
# 12800  16063  rt and is tugging her back, at least trying to...  thriller
# 10780  13537  ? DOUG I hope so! Momentary silence. KATKA If ...     drama
# 19394  24222  g, you're pitching very wild balls. What RESUM...     drama
# 21488  26836  owing the VW is a school bus. MERYL mocking Wh...     drama
#
# [6774 rows x 3 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15805 entries, 20162 to 17649
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      15805 non-null  object
#  1   text    15805 non-null  object
#  2   genre   15805 non-null  object
# dtypes: object(3)
# memory usage: 493.9+ KB

# %%
train_df.isnull().sum()
# Out:
# 0
# id       0
# text     0
# genre    0
# dtype: int64

# %%
plt.figure(figsize=(30,10))
sns.barplot(x=train_df['genre'].value_counts().index,y=train_df['genre'].value_counts())
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=90);

# %%
train_df['para_num']=train_df['text'].apply(len)

# %%
train_df
# Out:
# 0         id                                               text     genre  \
# 20162  25185  you around, just to make me laugh. 467A SHOT O...  thriller
# 2713    3406  right hand shakes off of the wheel a bit. He g...  thriller
# 20678  25827  sn't even have to be gold JOE How can you be s...    comedy
# 18711  23404  here. I used to have lunch with him. John Birc...     drama
# 7785    9797  leet Officers, jumping off the dish and flying...  thriller
# ...      ...                                                ...       ...
# 7972   10033  n emptiness began to grow There's something ou...     other
# 6519    8199  ther...? shrugs Probably stumbling home, propo...     other
# 16345  20439  ppears behind it. ANGLE BEHIND THE STATUE Dani...    action
# 10398  13058  if we don't move. This guy is everything they ...  thriller
# 17649  22068  couch preparing his morning joint. WAYNE She's...    action
#
# 0      para_num
# 20162      1000
# 2713       1000
# 20678      1000
# ...

# %%
#plotting the length graph
plt.figure(figsize=(20,10))
train_df['para_num'].plot(bins=100, kind='hist')

# %%
train_df.describe()
# Out:
# 0          para_num
# count  15805.000000
# mean     999.875356
# std        0.360022
# min      998.000000
# 25%     1000.000000
# 50%     1000.000000
# 75%     1000.000000
# max     1000.000000

# %%
def clean_text(text):
    text = text.lower()# lower-case all characters
    text =  re.sub(r'@\S+', '',text)# remove twitter handles
    text =  re.sub(r'http\S+', '',text)# remove urls
    text =  re.sub(r'pic.\S+', '',text)
    text =  re.sub(r"[^a-zA-Z+']", ' ',text)# only keeps characters
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text+' ')# keep words with length>1 only
    text = "".join([i for i in text if i not in string.punctuation])
    words = nltk.tokenize.word_tokenize(text)
    stopwords = nltk.corpus.stopwords.words('english')# remove stopwords
    text = " ".join([i for i in words if i not in stopwords and len(i)>2])
    text= re.sub("\s[\s]+", " ",text).strip()# remove repeated/leading/trailing spaces
    return text

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
train_df['Text_cleaning'] = train_df.text.apply(clean_text)

# %%
train_df
# Out:
# 0         id                                               text     genre  \
# 20162  25185  you around, just to make me laugh. 467A SHOT O...  thriller
# 2713    3406  right hand shakes off of the wheel a bit. He g...  thriller
# 20678  25827  sn't even have to be gold JOE How can you be s...    comedy
# 18711  23404  here. I used to have lunch with him. John Birc...     drama
# 7785    9797  leet Officers, jumping off the dish and flying...  thriller
# ...      ...                                                ...       ...
# 7972   10033  n emptiness began to grow There's something ou...     other
# 6519    8199  ther...? shrugs Probably stumbling home, propo...     other
# 16345  20439  ppears behind it. ANGLE BEHIND THE STATUE Dani...    action
# 10398  13058  if we don't move. This guy is everything they ...  thriller
# 17649  22068  couch preparing his morning joint. WAYNE She's...    action
#
# 0      para_num                                      Text_cleaning
# ...

# %%
test_df['Text_cleaning'] = test_df.text.apply(clean_text)

# %%
test_df
# Out:
# 0         id                                               text     genre  \
# 8390   10571   in a pantsuit, heels, and pink angora sweater...     drama
# 14689  18380  FILM EDITORS CONRAD BUFF MARK GOLDBLATT, A.C.E...  thriller
# 5399    6785  e house was a collection of 36 artifacts, all ...    comedy
# 2598    3263  could they have evolved so quickly...? David d...  thriller
# 13049  16361  ard on Korda's hair. Pushes the gun tighter ag...     drama
# ...      ...                                                ...       ...
# 20211  25247  s surprised to see her. She immediately crosse...    action
# 12800  16063  rt and is tugging her back, at least trying to...  thriller
# 10780  13537  ? DOUG I hope so! Momentary silence. KATKA If ...     drama
# 19394  24222  g, you're pitching very wild balls. What RESUM...     drama
# 21488  26836  owing the VW is a school bus. MERYL mocking Wh...     drama
#
# 0                                          Text_cleaning
# ...

# %%
train_df['len_clean_desc']=train_df['Text_cleaning'].apply(len)

# %%
train_df
# Out:
# 0         id                                               text     genre  \
# 20162  25185  you around, just to make me laugh. 467A SHOT O...  thriller
# 2713    3406  right hand shakes off of the wheel a bit. He g...  thriller
# 20678  25827  sn't even have to be gold JOE How can you be s...    comedy
# 18711  23404  here. I used to have lunch with him. John Birc...     drama
# 7785    9797  leet Officers, jumping off the dish and flying...  thriller
# ...      ...                                                ...       ...
# 7972   10033  n emptiness began to grow There's something ou...     other
# 6519    8199  ther...? shrugs Probably stumbling home, propo...     other
# 16345  20439  ppears behind it. ANGLE BEHIND THE STATUE Dani...    action
# 10398  13058  if we don't move. This guy is everything they ...  thriller
# 17649  22068  couch preparing his morning joint. WAYNE She's...    action
#
# 0      para_num                                      Text_cleaning  \
# ...

# %%
num_words = 50000
max_len = 300
tokenizer = Tokenizer(num_words=num_words, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(train_df['Text_cleaning'].values)

# %%
X = tokenizer.texts_to_sequences(train_df['Text_cleaning'].values)
X = pad_sequences(X, maxlen=max_len)
y = pd.get_dummies(train_df['genre']).values

X_test = tokenizer.texts_to_sequences(test_df['Text_cleaning'].values)
X_test = pad_sequences(X_test, maxlen=max_len)
y_test = pd.get_dummies(test_df['genre']).values

# %%
EMBEDDING_DIM = 100
model = Sequential()
model.add(Embedding(num_words, EMBEDDING_DIM, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.1, recurrent_dropout=0.2))
model.add(Dense(9, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
my_callbacks  = [EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=2,
                              mode='auto')]

# %%
X.shape
# Out:
# (15805, 300)

# %%
y.shape
# Out:
# (15805, 9)

# %%
X_test.shape
# Out:
# (6774, 300)

# %%
y_test.shape
# Out:
# (6774, 9)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 300, 100)          5000000
#
#  spatial_dropout1d_1 (Spatia  (None, 300, 100)         0
#  lDropout1D)
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense_1 (Dense)             (None, 9)                 909
#
# ...
# Total params: 5,081,309
# Trainable params: 5,081,309
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X, y, epochs=6,validation_data=(X_test,y_test), callbacks=my_callbacks)
# Out:
# Epoch 1/6
# 494/494 [==============================] - 368s 739ms/step - loss: 1.3762 - accuracy: 0.5023 - val_loss: 1.9112 - val_accuracy: 0.3975
# Epoch 2/6
# 494/494 [==============================] - 366s 741ms/step - loss: 0.7403 - accuracy: 0.7712 - val_loss: 0.7354 - val_accuracy: 0.7585
# Epoch 3/6
# 494/494 [==============================] - 382s 774ms/step - loss: 0.2963 - accuracy: 0.9114 - val_loss: 0.5304 - val_accuracy: 0.8462
# Epoch 4/6
# 494/494 [==============================] - 380s 769ms/step - loss: 0.1392 - accuracy: 0.9577 - val_loss: 0.5239 - val_accuracy: 0.8505
# Epoch 5/6
# 494/494 [==============================] - 378s 765ms/step - loss: 0.0845 - accuracy: 0.9754 - val_loss: 0.5681 - val_accuracy: 0.8694
# Epoch 6/6
# 494/494 [==============================] - 370s 749ms/step - loss: 0.0525 - accuracy: 0.9865 - val_loss: 0.5333 - val_accuracy: 0.8595

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show();

# Plotting loss and val_loss
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.53328
# Test Accuracy: 85.95%
